# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
x1 = pd.read_excel("xlsx (1).xlsx")
x2 = pd.read_excel("xlsx (2).xlsx")
x3 = pd.read_excel("xlsx (5).xlsx")
x4 = pd.read_excel("xlsx (6).xlsx")
x5 = pd.read_excel("xlsx (7).xlsx")
x6 = pd.read_excel("xlsx (8).xlsx")

# %%
merge_data = pd.concat([x1,x2,x3,x4,x5,x6])
merge_data
# Out:
#                   Date Time        Status  Speed(Km/h)  Latitude  Longitude  \
# 0     2023-05-25 - 00:16:12        Normal            0  24.95635   67.11983
# 1     2023-05-25 - 00:46:13        Normal            0  24.95635   67.11983
# 2     2023-05-25 - 01:16:13        Normal            0  24.95635   67.11983
# 3     2023-05-25 - 01:46:13        Normal            0  24.95635   67.11983
# 4     2023-05-25 - 02:16:13        Normal            0  24.95635   67.11983
# ...                     ...           ...          ...       ...        ...
# 1574  2023-02-05 - 21:35:06        Normal            9  28.39185   70.29641
# 1575  2023-02-05 - 21:35:09        Normal           26  28.39184   70.29641
# 1576  2023-02-05 - 21:35:10        Normal           13  28.39183   70.29642
# 1577  2023-02-05 - 21:35:53  Ignition Off            0  28.39181   70.29559
# 1578  2023-02-05 - 21:36:53        Normal            0  28.39182   70.29562
#
# ...

# %%
merge_data.reset_index(drop=True , inplace=True)

# %%
merge_data.dtypes
# Out:
# Date Time       object
# Status          object
# Speed(Km/h)      int64
# Latitude       float64
# Longitude      float64
# Reference       object
# Mileage          int64
# dtype: object

# %%
merge_data["Date Time"] = pd.to_datetime(merge_data["Date Time"])

# %%
merge_data[merge_data.duplicated()]
# Out:
#                 Date Time        Status  Speed(Km/h)  Latitude  Longitude  \
# 693   2023-05-25 19:23:21        Normal           36  24.88278   67.02135
# 1235  2023-05-26 09:25:24        Normal           77  24.91037   67.06838
# 2711  2023-05-27 14:52:27  Ignition Off            0  24.85648   67.00745
# 2712  2023-05-27 14:52:27  Ignition Off            0  24.85648   67.00745
# 9376  2023-03-14 08:50:41        Normal           12  24.90764   67.07853
# ...                   ...           ...          ...       ...        ...
# 30983 2023-02-05 12:27:20        Normal           94  25.84358   68.26366
# 31365 2023-02-05 16:14:26        Normal           90  27.08165   68.30872
# 31828 2023-02-05 19:27:22        Normal           88  28.31676   69.76142
# 31900 2023-02-05 20:05:46        Normal          105  28.39329   69.90354
# 32000 2023-02-05 20:36:58        Normal           70  28.58941   70.25054
#
#                                                Reference  Mileage
# ...

# %%
merge_data.iloc[692:694]
# Out:
#               Date Time  Status  Speed(Km/h)  Latitude  Longitude  \
# 692 2023-05-25 19:23:21  Normal           36  24.88278   67.02135
# 693 2023-05-25 19:23:21  Normal           36  24.88278   67.02135
#
#                                           Reference  Mileage
# 692  0.00 Km From Police Hospital, Garden - Karachi       24
# 693  0.00 Km From Police Hospital, Garden - Karachi       24

# %%
merge_data.drop_duplicates("Date Time",inplace=True)

# %%
merge_data.reset_index(drop=True , inplace=True)

# %%
merge_data
# Out:
#                 Date Time        Status  Speed(Km/h)  Latitude  Longitude  \
# 0     2023-05-25 00:16:12        Normal            0  24.95635   67.11983
# 1     2023-05-25 00:46:13        Normal            0  24.95635   67.11983
# 2     2023-05-25 01:16:13        Normal            0  24.95635   67.11983
# 3     2023-05-25 01:46:13        Normal            0  24.95635   67.11983
# 4     2023-05-25 02:16:13        Normal            0  24.95635   67.11983
# ...                   ...           ...          ...       ...        ...
# 31894 2023-02-05 21:35:06        Normal            9  28.39185   70.29641
# 31895 2023-02-05 21:35:09        Normal           26  28.39184   70.29641
# 31896 2023-02-05 21:35:10        Normal           13  28.39183   70.29642
# 31897 2023-02-05 21:35:53  Ignition Off            0  28.39181   70.29559
# 31898 2023-02-05 21:36:53        Normal            0  28.39182   70.29562
#
#                                                Reference  Mileage
# ...

# %%
ignition = merge_data[(merge_data["Status"] == "Ignition On") | (merge_data["Status"] == "Ignition Off")]
ignition
# Out:
#                 Date Time        Status  Speed(Km/h)  Latitude  Longitude  \
# 18    2023-05-25 09:05:19   Ignition On            0  24.95635   67.11983
# 408   2023-05-25 09:36:15  Ignition Off            0  24.85659   67.00736
# 428   2023-05-25 19:02:38   Ignition On            0  24.85659   67.00736
# 993   2023-05-25 19:46:47  Ignition Off            0  24.95629   67.11987
# 1021  2023-05-26 09:08:26   Ignition On            0  24.95629   67.11987
# ...                   ...           ...          ...       ...        ...
# 31887 2023-02-05 21:29:24  Ignition Off            0  28.39186   70.29645
# 31888 2023-02-05 21:29:32   Ignition On            0  28.39186   70.29645
# 31889 2023-02-05 21:29:37  Ignition Off            0  28.39186   70.29645
# 31891 2023-02-05 21:34:42   Ignition On            0  28.39186   70.29645
# 31897 2023-02-05 21:35:53  Ignition Off            0  28.39181   70.29559
#
#                                                Reference  Mileage
# ...

# %%
index = pd.Series(merge_data[(merge_data["Status"] == "Ignition On") | (merge_data["Status"] == "Ignition Off")].index)
index
# Out:
# 0         18
# 1        408
# 2        428
# 3        993
# 4       1021
#        ...
# 281    31887
# 282    31888
# 283    31889
# 284    31891
# 285    31897
# Length: 286, dtype: int64

# %%
trip1 = merge_data.iloc[18:409]
trip1
# Out:
#               Date Time                 Status  Speed(Km/h)  Latitude  \
# 18  2023-05-25 09:05:19            Ignition On            0  24.95635
# 19  2023-05-25 09:05:25                 Normal            0  24.95635
# 20  2023-05-25 09:05:30                 Normal            0  24.95635
# 21  2023-05-25 09:05:35                 Normal            0  24.95635
# 22  2023-05-25 09:05:40                 Normal            0  24.95635
# ..                  ...                    ...          ...       ...
# 404 2023-05-25 09:35:58                 Normal            0  24.85659
# 405 2023-05-25 09:36:02  Driver SeatBelt Close            0  24.85659
# 406 2023-05-25 09:36:07                 Normal            0  24.85659
# 407 2023-05-25 09:36:12                 Normal            0  24.85659
# 408 2023-05-25 09:36:15           Ignition Off            0  24.85659
#
#      Longitude                                          Reference  Mileage
# ...

# %%
plt.figure(figsize=(12,6)) 
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.show()

# %%
plt.figure(figsize=(12,6)) 
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.scatter(trip1["Longitude"][18],trip1["Latitude"][18],linewidth=10 , color = "blue")
plt.scatter(trip1["Longitude"][408],trip1["Latitude"][408],linewidth=10 , color = "purple")
plt.show()

# %%
trip1_overspeed = trip1[trip1["Speed(Km/h)"] >= 80]
trip1_overspeed
# Out:
#               Date Time  Status  Speed(Km/h)  Latitude  Longitude  \
# 182 2023-05-25 09:18:20  Normal           82  24.92743   67.08607
# 183 2023-05-25 09:18:25  Normal           80  24.92699   67.08506
# 184 2023-05-25 09:18:30  Normal           80  24.92665   67.08426
# 185 2023-05-25 09:18:34  Normal           81  24.92621   67.08325
# 192 2023-05-25 09:19:06  Normal           82  24.92118   67.08015
# 193 2023-05-25 09:19:10  Normal           85  24.92013   67.07997
# 194 2023-05-25 09:19:15  Normal           86  24.91929   67.07984
# 195 2023-05-25 09:19:19  Normal           84  24.91822   67.07967
# 198 2023-05-25 09:19:32  Normal           80  24.91571   67.07926
# 199 2023-05-25 09:19:36  Normal           84  24.91471   67.07890
# 200 2023-05-25 09:19:41  Normal           85  24.91397   67.07844
# 201 2023-05-25 09:19:45  Normal           83  24.91321   67.07763
# 202 2023-05-25 09:19:50  Normal           81  24.91280   67.07685
# ...

# %%
plt.figure(figsize=(12,6)) 
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.plot(trip1_overspeed["Longitude"],trip1_overspeed["Latitude"] , linewidth = 5 , color = "red")
plt.scatter(trip1["Longitude"][18],trip1["Latitude"][18],linewidth=10 , color = "blue")
plt.scatter(trip1["Longitude"][408],trip1["Latitude"][408],linewidth=10 , color = "purple")
plt.show()

# %%
trip1[ (trip1["Status"] == "Driver SeatBelt Close") | (trip1["Status"] == "Driver SeatBelt Open")]
# Out:
#               Date Time                 Status  Speed(Km/h)  Latitude  \
# 34  2023-05-25 09:06:39   Driver SeatBelt Open            0  24.95635
# 405 2023-05-25 09:36:02  Driver SeatBelt Close            0  24.85659
#
#      Longitude                                          Reference  Mileage
# 34    67.11983  0.00 Km From Memon Resturant, Sachal Goth - Ka...        0
# 405   67.00736  0.00 Km From CPLC Parking, Court St, Ali Dina ...       20

# %%
plt.figure(figsize=(15,8)) 
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.plot(trip1_overspeed["Longitude"],trip1_overspeed["Latitude"] , linewidth = 5 , color = "red")
plt.scatter(trip1["Longitude"][18],trip1["Latitude"][18],linewidth=10 , color = "blue")
plt.scatter(trip1["Longitude"][408],trip1["Latitude"][408],linewidth=10 , color = "purple")
plt.scatter(trip1["Longitude"][34],trip1["Latitude"][34] , color = "orange")
plt.scatter(trip1["Longitude"][405],trip1["Latitude"][405] , color = "yellow")
plt.show()

# %%
harsh_speed = []
speed = 0
for ind,i in trip1.iterrows():
    if i["Speed(Km/h)"] >= speed+20 :
        harsh_speed.append(ind)
    if speed <= i["Speed(Km/h)"]:
        speed = i["Speed(Km/h)"]
    if speed > i["Speed(Km/h)"] :
        speed = i["Speed(Km/h)"]

# %%
harsh_speed
# Out:
# [78, 96, 164]

# %%
plt.figure(figsize=(15,8)) 
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.plot(trip1_overspeed["Longitude"],trip1_overspeed["Latitude"] , linewidth = 5 , color = "red")
plt.scatter(trip1["Longitude"][18],trip1["Latitude"][18],linewidth=10 , color = "blue")
plt.scatter(trip1["Longitude"][408],trip1["Latitude"][408],linewidth=10 , color = "purple")
plt.scatter(trip1["Longitude"][34],trip1["Latitude"][34] , color = "orange")
plt.scatter(trip1["Longitude"][405],trip1["Latitude"][405] , color = "yellow")
for i in harsh_speed:
    plt.scatter(trip1["Longitude"][i],trip1["Latitude"][i] ,linewidth=10 ,color = "Red")
plt.show()

# %%
harsh_brake = []
brake = 0
for ind,i in trip1.iterrows():
    if i["Speed(Km/h)"] <= brake-20 :
        harsh_brake.append(ind)
    if brake <= i["Speed(Km/h)"]:
        brake = i["Speed(Km/h)"]
    if brake > i["Speed(Km/h)"] :
        brake = i["Speed(Km/h)"]

# %%
harsh_brake
# Out:
# [75]

# %%
Duration = trip1["Date Time"][408] - trip1["Date Time"][18]

# %%
plt.figure(figsize=(15,8)) 
print(f"The Duration of Trip 1 is : {Duration} , No. of Harsh Speed is : \
{len(harsh_speed)} , No. of Harsh Break is : {len(harsh_brake)}")
plt.plot(trip1["Longitude"],trip1["Latitude"] , ls = "--" , color = "green")
plt.plot(trip1_overspeed["Longitude"],trip1_overspeed["Latitude"] , linewidth = 5 , color = "red")
plt.scatter(trip1["Longitude"][18],trip1["Latitude"][18],linewidth=10 , color = "blue")
plt.scatter(trip1["Longitude"][408],trip1["Latitude"][408],linewidth=10 , color = "purple")
plt.scatter(trip1["Longitude"][34],trip1["Latitude"][34] , color = "orange")
plt.scatter(trip1["Longitude"][405],trip1["Latitude"][405] , color = "yellow")
for i in harsh_speed:
    plt.scatter(trip1["Longitude"][i],trip1["Latitude"][i] ,linewidth=10 ,color = "Red")
plt.scatter(trip1["Longitude"][75],trip1["Latitude"][75] ,linewidth=10 ,color = "Brown")
plt.show()
# Out:
# The Duration of Trip 1 is : 0 days 00:30:56 , No. of Harsh Speed is : 3 , No. of Harsh Break is : 1

# %%
on_list = []
off_list = []
for ind,i in ignition.iterrows():
    if i["Status"] == "Ignition On":
        on_list.append(ind) 
    if i["Status"] == "Ignition Off":
        off_list.append(ind+1)    

index_list = []
for i in range(143):
    index_list.append([on_list[i],off_list[i]])
index_list
# Out:
# [[18, 409],
#  [428, 994],
#  [1021, 1431],
#  [1450, 2110],
#  [2111, 2168],
#  [2200, 2634],
#  [2635, 2645],
#  [2645, 2653],
#  [2657, 2679],
#  [2681, 2709],
#  [2715, 3177],
#  [3179, 3405],
#  [3406, 3451],
#  [3458, 4439],
#  [4281, 4550],
#  [4445, 4842],
#  [4551, 4973],
#  [4848, 5235],
#  [4974, 5243],
#  [5236, 5250],
#  [5244, 5415],
#  [5253, 6012],
#  [5417, 6413],
#  [6018, 6824],
#  [6418, 7084],
#  [6824, 7563],
#  [7085, 7889],
#  [7580, 8139],
#  [7898, 8208],
#  [8141, 8404],
#  [8212, 8985],
#  [8417, 9193],
#  [9002, 9314],
#  [9196, 9338],
#  [9315, 9383],
#  [9339, 9438],
#  [9384, 9451],
#  [9440, 9743],
#  [9452, 9783],
#  [9744, 9860],
#  [9784, 10153],
#  [9861, 10519],
#  [10154, 10751],
#  [10520, 10865],
#  [10752, 11112],
#  [10867, 11910],
#  [11113, 11933],
#  [11911, 12290],
#  [11935, 12425],
#  [12290, 12636],
#  [12452, 12723],
#  [12640, 12725],
#  [12723, 12798],
#  [12726, 13094],
#  [12800, 13209],
#  [13102, 13413],
#  [13210, 13421],
# ...

# %%
trip = {}
j = 1
for i in index_list:
    name = f"trip{j}"
    value = merge_data.iloc[i[0]:i[1]]
    trip[name] = value
    j += 1

# %%
def data(col):
    
    col.reset_index(drop=True , inplace=True)
    
    harsh_speed = []
    speed = 0
    
    for ind,i in col.iterrows():
        if i["Speed(Km/h)"] >= speed+20 :
            harsh_speed.append(ind)
        if speed <= i["Speed(Km/h)"]:
            speed = i["Speed(Km/h)"]
        if speed > i["Speed(Km/h)"] :
            speed = i["Speed(Km/h)"]
            
    harsh_brake = []
    brake = 0
    
    for ind,i in col.iterrows():
        if i["Speed(Km/h)"] <= brake-20 :
            harsh_brake.append(ind)
        if brake <= i["Speed(Km/h)"]:
            brake = i["Speed(Km/h)"]
        if brake > i["Speed(Km/h)"] :
            brake = i["Speed(Km/h)"]       
    
    over_speed = col[col["Speed(Km/h)"] >= 80]
    
    closed = col[col["Status"] == "Driver SeatBelt Close"]
    opened = col[col["Status"] == "Driver SeatBelt Open"]
    
    plt.figure(figsize=(15,8)) 
    
    Duration = col["Date Time"].iloc[-1] - col["Date Time"].iloc[0]
    print(f"The Duration of this Trip is : {Duration} , No. of Harsh Speed is : {len(harsh_speed)} \
, No. of Harsh Break is : {len(harsh_brake)}")
    
    plt.plot(col["Longitude"],col["Latitude"] , ls = "--" , color = "green")
    plt.scatter(col["Longitude"][0:1],col["Latitude"][0:1],linewidth=10 , color = "blue")
    plt.scatter(col["Longitude"][-1:],col["Latitude"][-1:],linewidth=10 , color = "purple")
   
    plt.plot(over_speed["Longitude"],over_speed["Latitude"] , linewidth = 5 , color = "red")
    
    plt.scatter(closed["Longitude"],closed["Latitude"] ,  linewidth = 5, color = "orange")
    plt.scatter(opened["Longitude"],opened["Latitude"] ,linewidth = 5 , color = "yellow")
    
    for i in harsh_speed:
        plt.scatter(col["Longitude"][i],col["Latitude"][i] ,linewidth=10 ,color = "Red")
        
    for i in harsh_brake:
        plt.scatter(col["Longitude"][i],col["Latitude"][i] ,linewidth=7 ,color = "Grey")
    
    plt.show()

# %%
data(trip["trip2"])
# Out:
# The Duration of this Trip is : 0 days 00:44:09 , No. of Harsh Speed is : 2 , No. of Harsh Break is : 6

# %%
trip["trip8"]
# Out:
#                Date Time        Status  Speed(Km/h)  Latitude  Longitude  \
# 2645 2023-05-27 12:32:21   Ignition On            0  24.85636   67.00742
# 2646 2023-05-27 12:32:26        Normal            0  24.85636   67.00742
# 2647 2023-05-27 12:32:31        Normal            4  24.85636   67.00741
# 2648 2023-05-27 12:32:36        Normal            1  24.85637   67.00739
# 2649 2023-05-27 12:32:39        Normal            6  24.85637   67.00739
# 2650 2023-05-27 12:32:40        Normal            8  24.85640   67.00739
# 2651 2023-05-27 12:32:46        Normal           13  24.85653   67.00729
# 2652 2023-05-27 12:32:51  Ignition Off            0  24.85658   67.00727
#
#                                               Reference  Mileage
# 2645  0.00 Km From CPLC Parking, Court St, Ali Dina ...      104
# 2646  0.00 Km From CPLC Parking, Court St, Ali Dina ...      104
# 2647  0.00 Km From CPLC Parking, Court St, Ali Dina ...      104
# ...
